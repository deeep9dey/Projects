# %%
import pandas as pd

# %% [markdown]
# # Answer 1(i)

# %%
customer_details=pd.read_csv(r'C:\Users\Vivobook S14\OneDrive\Desktop\Python\Project On EDA\customer_details.csv')
customer_details.columns=['customer_id','Gender','age','driving licence present',' region code',' previously insured','vehicle age','vehicle damage']
customer_details
# Out:
#         customer_id  Gender   age  driving licence present   region code  \
# 0               2.0    Male  76.0                      1.0           3.0
# 1               3.0    Male  47.0                      1.0          28.0
# 2               4.0    Male  21.0                      1.0          11.0
# 3               5.0  Female  29.0                      1.0          41.0
# 4               6.0  Female  24.0                      1.0          33.0
# ...             ...     ...   ...                      ...           ...
# 381103     381105.0    Male  74.0                      1.0          26.0
# 381104     381106.0    Male  30.0                      1.0          37.0
# 381105     381107.0    Male  21.0                      1.0          30.0
# 381106     381108.0  Female  68.0                      1.0          14.0
# 381107     381109.0    Male  46.0                      1.0          29.0
#
#          previously insured vehicle age vehicle damage
# ...

# %% [markdown]
# # Answer 1(ii)

# %%
customer_policy_details=pd.read_csv(r'C:\Users\Vivobook S14\OneDrive\Desktop\Python\Project On EDA\customer_policy_details.csv')
customer_policy_details.columns=['customer_id','annual premium (in Rs)','sales channel code','vintage','response']
customer_policy_details
# Out:
#         customer_id  annual premium (in Rs)  sales channel code  vintage  \
# 0               1.0                 40454.0                26.0    217.0
# 1               2.0                 33536.0                26.0    183.0
# 2               3.0                 38294.0                26.0     27.0
# 3               4.0                 28619.0               152.0    203.0
# 4               5.0                 27496.0               152.0     39.0
# ...             ...                     ...                 ...      ...
# 381104     381105.0                 30170.0                26.0     88.0
# 381105     381106.0                 40016.0               152.0    131.0
# 381106     381107.0                 35118.0               160.0    161.0
# 381107     381108.0                 44617.0               124.0     74.0
# 381108     381109.0                 41777.0                26.0    237.0
#
#         response
# 0            1.0
# 1            0.0
# 2            1.0
# 3            0.0
# ...

# %% [markdown]
# # Answer 2(Null Values)

# %%
# Generate a summary of count of all the null values column wise.
customer_details.isnull().sum()
# Out:
# customer_id                  0
# Gender                     368
# age                          0
# driving licence present      0
#  region code                 0
#  previously insured          0
# vehicle age                381
# vehicle damage             406
# dtype: int64

# %%
# Drop Null values for customer_id because central tendencies for id’s is not feasible.
customer_details['customer_id'].dropna(axis=0,inplace=True)
customer_details
# Out:
#         customer_id  Gender   age  driving licence present   region code  \
# 0               2.0    Male  76.0                      1.0           3.0
# 1               3.0    Male  47.0                      1.0          28.0
# 2               4.0    Male  21.0                      1.0          11.0
# 3               5.0  Female  29.0                      1.0          41.0
# 4               6.0  Female  24.0                      1.0          33.0
# ...             ...     ...   ...                      ...           ...
# 381103     381105.0    Male  74.0                      1.0          26.0
# 381104     381106.0    Male  30.0                      1.0          37.0
# 381105     381107.0    Male  21.0                      1.0          30.0
# 381106     381108.0  Female  68.0                      1.0          14.0
# 381107     381109.0    Male  46.0                      1.0          29.0
#
#          previously insured vehicle age vehicle damage
# ...

# %%
# Replace all null values for numeric columns by mean. 
customer_details['customer_id'].fillna(customer_details['customer_id'].mean())

# %%
# Replace all null values for numeric columns by mean. 
customer_details['age'].fillna(customer_details['age'].mean())
# Out:
# 0         76.0
# 1         47.0
# 2         21.0
# 3         29.0
# 4         24.0
#           ...
# 381103    74.0
# 381104    30.0
# 381105    21.0
# 381106    68.0
# 381107    46.0
# Name: age, Length: 381108, dtype: float64

# %%
# Replace all null values for numeric columns by mean. 
customer_details['driving licence present'].fillna(customer_details['driving licence present'].mean())
# Out:
# 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#          ...
# 381103    1.0
# 381104    1.0
# 381105    1.0
# 381106    1.0
# 381107    1.0
# Name: driving licence present, Length: 381108, dtype: float64

# %%
# Replace all null values for numeric columns by mean. 
customer_details[' region code'].fillna(customer_details[' region code'].mean())
# Out:
# 0          3.0
# 1         28.0
# 2         11.0
# 3         41.0
# 4         33.0
#           ...
# 381103    26.0
# 381104    37.0
# 381105    30.0
# 381106    14.0
# 381107    29.0
# Name:  region code, Length: 381108, dtype: float64

# %%
# Replace all null values for numeric columns by mean. 
customer_details[' previously insured'].fillna(customer_details[' previously insured'].mean())
# Out:
# 0         0.0
# 1         0.0
# 2         1.0
# 3         1.0
# 4         0.0
#          ...
# 381103    1.0
# 381104    1.0
# 381105    1.0
# 381106    0.0
# 381107    0.0
# Name:  previously insured, Length: 381108, dtype: float64

# %%
# Replace all null values for Categorical value by mode.
customer_details['Gender'].fillna(customer_details['Gender'].mode()[0])
# Out:
# 0           Male
# 1           Male
# 2           Male
# 3         Female
# 4         Female
#            ...
# 381103      Male
# 381104      Male
# 381105      Male
# 381106    Female
# 381107      Male
# Name: Gender, Length: 381108, dtype: object

# %%
# Replace all null values for Categorical value by mode.
customer_details['age'].fillna(customer_details['age'].mode()[0])
# Out:
# 0         76.0
# 1         47.0
# 2         21.0
# 3         29.0
# 4         24.0
#           ...
# 381103    74.0
# 381104    30.0
# 381105    21.0
# 381106    68.0
# 381107    46.0
# Name: age, Length: 381108, dtype: float64

# %%
# Replace all null values for Categorical value by mode.
customer_details['driving licence present'].fillna(customer_details['driving licence present'].mode()[0])
# Out:
# 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#          ...
# 381103    1.0
# 381104    1.0
# 381105    1.0
# 381106    1.0
# 381107    1.0
# Name: driving licence present, Length: 381108, dtype: float64

# %%
# Replace all null values for Categorical value by mode.
customer_details[' region code'].fillna(customer_details[' region code'].mode()[0])
# Out:
# 0          3.0
# 1         28.0
# 2         11.0
# 3         41.0
# 4         33.0
#           ...
# 381103    26.0
# 381104    37.0
# 381105    30.0
# 381106    14.0
# 381107    29.0
# Name:  region code, Length: 381108, dtype: float64

# %%
# Replace all null values for Categorical value by mode.
customer_details[' previously insured'].fillna(customer_details[' previously insured'].mode()[0])
# Out:
# 0         0.0
# 1         0.0
# 2         1.0
# 3         1.0
# 4         0.0
#          ...
# 381103    1.0
# 381104    1.0
# 381105    1.0
# 381106    0.0
# 381107    0.0
# Name:  previously insured, Length: 381108, dtype: float64

# %%
# Replace all null values for Categorical value by mode.
customer_details['vehicle age'].fillna(customer_details['vehicle age'].mode()[0])
# Out:
# 0          1-2 Year
# 1         > 2 Years
# 2          < 1 Year
# 3          < 1 Year
# 4          < 1 Year
#             ...
# 381103     1-2 Year
# 381104     < 1 Year
# 381105     < 1 Year
# 381106    > 2 Years
# 381107     1-2 Year
# Name: vehicle age, Length: 381108, dtype: object

# %%
# Replace all null values for Categorical value by mode.
customer_details['vehicle damage'].fillna(customer_details['vehicle damage'].mode()[0])
# Out:
# 0          No
# 1         Yes
# 2          No
# 3          No
# 4         Yes
#          ...
# 381103     No
# 381104     No
# 381105     No
# 381106    Yes
# 381107     No
# Name: vehicle damage, Length: 381108, dtype: object

# %% [markdown]
# # Outliers

# %%
customer_details.describe()
# Out:
#          customer_id            age  driving licence present    region code  \
# count  380722.000000  380722.000000            380722.000000  380722.000000
# mean   190549.276735      38.822774                 0.997868      26.389432
# std    110016.516220      15.504844                 0.046105      13.223688
# min         2.000000      20.000000                 0.000000       0.000000
# 25%     95270.250000      25.000000                 1.000000      15.000000
# 50%    190543.500000      36.000000                 1.000000      28.000000
# 75%    285822.750000      49.000000                 1.000000      35.000000
# max    381109.000000      85.000000                 1.000000      52.000000
#
#         previously insured
# count        380722.000000
# mean              0.458260
# std               0.498006
# min               0.000000
# 25%               0.000000
# 50%               0.000000
# 75%               1.000000
# max               1.000000

# %%
# Generate a summary of count of all the outliers column wise
Q1=customer_details.describe().loc["25%","age"]
Q3=customer_details.describe().loc["75%","age"]
IQR=Q3-Q1
print(customer_details.loc[customer_details["age"]<(Q1-IQR*1.5),"age"].count())
print(customer_details.loc[customer_details["age"]>(Q3+IQR*1.5),"age"].count())
# Out:
# 0
# 0

# %%
# Generate a summary of count of all the outliers column wise
Q1=customer_details.describe().loc["25%","driving licence present"]
Q3=customer_details.describe().loc["75%","driving licence present"]
IQR=Q3-Q1
print(customer_details.loc[customer_details["driving licence present"]<(Q1-IQR*1.5),"driving licence present"].count())
print(customer_details.loc[customer_details["driving licence present"]>(Q3+IQR*1.5),"driving licence present"].count())
# Out:
# 812
# 0

# %%
# Generate a summary of count of all the outliers column wise
Q1=customer_details.describe().loc["25%"," region code"]
Q3=customer_details.describe().loc["75%"," region code"]
IQR=Q3-Q1
print(customer_details.loc[customer_details[" region code"]<(Q1-IQR*1.5)," region code"].count())
print(customer_details.loc[customer_details[" region code"]>(Q3+IQR*1.5)," region code"].count())
# Out:
# 0
# 0

# %%
# Generate a summary of count of all the outliers column wise
Q1=customer_details.describe().loc["25%"," previously insured"]
Q3=customer_details.describe().loc["75%"," previously insured"]
IQR=Q3-Q1
print(customer_details.loc[customer_details[" previously insured"]<(Q1-IQR*1.5)," previously insured"].count())
print(customer_details.loc[customer_details[" previously insured"]>(Q3+IQR*1.5)," previously insured"].count())
# Out:
# 0
# 0

# %%
customer_policy_details.describe()
# Out:
#          customer_id  annual premium (in Rs)  sales channel code  \
# count  380722.000000           380763.000000       380709.000000
# mean   190547.491663            30563.700273          112.035752
# std    110013.824148            17200.257877           54.204942
# min         1.000000             2630.000000            1.000000
# 25%     95276.250000            24406.000000           29.000000
# 50%    190536.500000            31668.000000          133.000000
# 75%    285818.750000            39400.000000          152.000000
# max    381109.000000           540165.000000          163.000000
#
#              vintage       response
# count  380721.000000  380748.000000
# mean      154.342437       0.122543
# std        83.669600       0.327912
# min        10.000000       0.000000
# 25%        82.000000       0.000000
# 50%       154.000000       0.000000
# 75%       227.000000       0.000000
# max       299.000000       1.000000

# %%
# Generate a summary of count of all the outliers column wise
Q1=customer_policy_details.describe().loc["25%","annual premium (in Rs)"]
Q3=customer_policy_details.describe().loc["75%","annual premium (in Rs)"]
IQR=Q3-Q1
print(customer_policy_details.loc[customer_policy_details["annual premium (in Rs)"]<(Q1-IQR*1.5),"annual premium (in Rs)"].count())
print(customer_policy_details.loc[customer_policy_details["annual premium (in Rs)"]>(Q3+IQR*1.5),"annual premium (in Rs)"].count())
# Out:
# 0
# 10308

# %%
# Generate a summary of count of all the outliers column wise
Q1=customer_policy_details.describe().loc["25%","sales channel code"]
Q3=customer_policy_details.describe().loc["75%","sales channel code"]
IQR=Q3-Q1
print(customer_policy_details.loc[customer_policy_details["sales channel code"]<(Q1-IQR*1.5),"sales channel code"].count())
print(customer_policy_details.loc[customer_policy_details["sales channel code"]>(Q3+IQR*1.5),"sales channel code"].count())
# Out:
# 0
# 0

# %%
# Generate a summary of count of all the outliers column wise
Q1=customer_policy_details.describe().loc["25%","vintage"]
Q3=customer_policy_details.describe().loc["75%","vintage"]
IQR=Q3-Q1
print(customer_policy_details.loc[customer_policy_details["vintage"]<(Q1-IQR*1.5),"vintage"].count())
print(customer_policy_details.loc[customer_policy_details["vintage"]>(Q3+IQR*1.5),"vintage"].count())
# Out:
# 0
# 0

# %%
# Generate a summary of count of all the outliers column wise
Q1=customer_policy_details.describe().loc["25%","response"]
Q3=customer_policy_details.describe().loc["75%","response"]
IQR=Q3-Q1
print(customer_policy_details.loc[customer_policy_details["response"]<(Q1-IQR*1.5),"response"].count())
print(customer_policy_details.loc[customer_policy_details["response"]>(Q3+IQR*1.5),"response"].count())
# Out:
# 0
# 46658

# %%
# Replace all outlier values for numeric columns by mean. 
customer_policy_details.loc[customer_policy_details["annual premium (in Rs)"]>(Q3+IQR*1.5),"annual premium (in Rs)"]=customer_policy_details["annual premium (in Rs)"].mean()
print(customer_policy_details.loc[customer_policy_details["annual premium (in Rs)"]>(Q3+IQR*1.5),"annual premium (in Rs)"].count())
# Out:
# 380763

# %%
# Replace all outlier values for numeric columns by mean. 
customer_policy_details.loc[customer_policy_details["sales channel code"]>(Q3+IQR*1.5),"sales channel code"]=customer_policy_details["sales channel code"].mean()
print(customer_policy_details.loc[customer_policy_details["sales channel code"]>(Q3+IQR*1.5),"sales channel code"].count())
# Out:
# 380709

# %%
# Replace all outlier values for numeric columns by mean. 
customer_policy_details.loc[customer_policy_details["vintage"]>(Q3+IQR*1.5),"vintage"]=customer_policy_details["vintage"].mean()
print(customer_policy_details.loc[customer_policy_details["vintage"]>(Q3+IQR*1.5),"vintage"].count())
# Out:
# 380721

# %%
# Replace all outlier values for numeric columns by mean. 
customer_policy_details.loc[customer_policy_details["response"]>(Q3+IQR*1.5),"response"]=customer_policy_details["response"].mean()
print(customer_policy_details.loc[customer_policy_details["response"]>(Q3+IQR*1.5),"response"].count())
# Out:
# 46658

# %% [markdown]
# # Remove White Spaces

# %%
customer_details["Gender"]=customer_details["Gender"].str.strip()
customer_details["vehicle age"]=customer_details["vehicle age"].str.strip()
customer_details["vehicle damage"]=customer_details["vehicle damage"].str.strip()

# %% [markdown]
# # case correction(lower or upper, any one)

# %%
customer_details["Gender"]=customer_details["Gender"].str.lower()
customer_details["vehicle age"]=customer_details["vehicle age"].str.lower()
customer_details["vehicle damage"]=customer_details["vehicle damage"].str.lower()
customer_details
# Out:
#         customer_id  Gender   age  driving licence present   region code  \
# 0               2.0    male  76.0                      1.0           3.0
# 1               3.0    male  47.0                      1.0          28.0
# 2               4.0    male  21.0                      1.0          11.0
# 3               5.0  female  29.0                      1.0          41.0
# 4               6.0  female  24.0                      1.0          33.0
# ...             ...     ...   ...                      ...           ...
# 381103     381105.0    male  74.0                      1.0          26.0
# 381104     381106.0    male  30.0                      1.0          37.0
# 381105     381107.0    male  21.0                      1.0          30.0
# 381106     381108.0  female  68.0                      1.0          14.0
# 381107     381109.0    male  46.0                      1.0          29.0
#
#          previously insured vehicle age vehicle damage
# ...

# %% [markdown]
# # Convert nominal data (categorical) into dummies

# %%
gender=pd.get_dummies(customer_details["Gender"])
age=pd.get_dummies(customer_details["age"])
driving_licence_present=pd.get_dummies(customer_details["driving licence present"])
region_code=pd.get_dummies(customer_details[" region code"])
previously_insured=pd.get_dummies(customer_details[" previously insured"])
vehicle_age=pd.get_dummies(customer_details["vehicle age"])
vehicle_damage=pd.get_dummies(customer_details["vehicle damage"])
annual_prem=pd.get_dummies(customer_policy_details["annual premium (in Rs)"])
sales=pd.get_dummies(customer_policy_details["sales channel code"])
vintage=pd.get_dummies(customer_policy_details["vintage"])
response=pd.get_dummies(customer_policy_details["response"])

# %%
print(customer_details.duplicated().sum())
print(customer_policy_details.duplicated().sum())
# Out:
# 0
# 0

# %% [markdown]
# # Answer 3

# %%
master=pd.merge(customer_details,customer_policy_details, on='customer_id')
master
# Out:
#         customer_id  Gender   age  driving licence present   region code  \
# 0               2.0    Male  76.0                      1.0           3.0
# 1               3.0    Male  47.0                      1.0          28.0
# 2               4.0    Male  21.0                      1.0          11.0
# 3               5.0  Female  29.0                      1.0          41.0
# 4               6.0  Female  24.0                      1.0          33.0
# ...             ...     ...   ...                      ...           ...
# 380330     381105.0    Male  74.0                      1.0          26.0
# 380331     381106.0    Male  30.0                      1.0          37.0
# 380332     381107.0    Male  21.0                      1.0          30.0
# 380333     381108.0  Female  68.0                      1.0          14.0
# 380334     381109.0    Male  46.0                      1.0          29.0
#
#          previously insured vehicle age vehicle damage  \
# ...

# %% [markdown]
# # Answer 4(i)

# %%
df1=master.groupby(["Gender"])["annual premium (in Rs)"].mean()
df1
# Out:
# Gender
# Female    30491.959528
# Male      30624.626538
# Name: annual premium (in Rs), dtype: float64

# %% [markdown]
# # Answer 4(ii)

# %%
df2=master.groupby(["age"])["annual premium (in Rs)"].mean()
df2
# Out:
# age
# 20.0    30563.700273
# 21.0    30563.700273
# 22.0    30563.700273
# 23.0    30563.700273
# 24.0    30563.700273
#             ...
# 81.0    30563.700273
# 82.0    30563.700273
# 83.0    30563.700273
# 84.0    30563.700273
# 85.0    30563.700273
# Name: annual premium (in Rs), Length: 66, dtype: float64

# %% [markdown]
# # Answer 4(iii)

# %%
Data is balanced because number of counts in each Gender group is approximately same

# %% [markdown]
# # Answer 4(iv)

# %%
df3=master.groupby(["vehicle age"])["annual premium (in Rs)"].mean()
df3

# %% [markdown]
# # Answer 5

# %%
Correlation_coefficient=master["age"].corr(master["annual premium (in Rs)"])
print(Correlation_coefficient)
# Out:
# 3.327162712407015e-16

# %%
Ther is a strong relationship between Person Age and annual premium because Correlation coefficient>0.5

# %%
dir(customer_details)
# Out:
# ['Gender',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...
